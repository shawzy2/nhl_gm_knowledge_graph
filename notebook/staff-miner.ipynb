# %%
# # Install a conda package in the current Jupyter kernel
# import sys
# !conda install --yes --prefix {sys.prefix} urllib3

# %%
import requests
import pprint
import os
import json
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd

import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# ### Parse list of NHL team links

# %%
# get list of links to NHL team pages
team_and_links = {}

try:
    url = 'https://www.eliteprospects.com/league/nhl'
    page = urlopen(url)
    html = page.read().decode("utf-8")
    soup = BeautifulSoup(html, 'html.parser')
    
    teams_tags = soup.find('div', {'class': 'leg-home-inner'}).find_all('a')
    for tag in teams_tags:
        team_name = tag.get_text().strip()
        team_link = tag.get('href')
        team_and_links[team_name] = team_link
        
except Exception as e:
    print('failed on page ' + url)
    print(e)

# %%
for team_name, team_link in team_and_links.items():
    print(team_link)
# Out:
# https://www.eliteprospects.com/team/1580/anaheim-ducks
# https://www.eliteprospects.com/team/72/arizona-coyotes
# https://www.eliteprospects.com/team/52/boston-bruins
# https://www.eliteprospects.com/team/53/buffalo-sabres
# https://www.eliteprospects.com/team/54/calgary-flames
# https://www.eliteprospects.com/team/55/carolina-hurricanes
# https://www.eliteprospects.com/team/56/chicago-blackhawks
# https://www.eliteprospects.com/team/57/colorado-avalanche
# https://www.eliteprospects.com/team/58/columbus-blue-jackets
# https://www.eliteprospects.com/team/59/dallas-stars
# https://www.eliteprospects.com/team/60/detroit-red-wings
# https://www.eliteprospects.com/team/61/edmonton-oilers
# https://www.eliteprospects.com/team/62/florida-panthers
# https://www.eliteprospects.com/team/79/los-angeles-kings
# https://www.eliteprospects.com/team/63/minnesota-wild
# https://www.eliteprospects.com/team/64/montreal-canadiens
# https://www.eliteprospects.com/team/65/nashville-predators
# https://www.eliteprospects.com/team/66/new-jersey-devils
# https://www.eliteprospects.com/team/67/new-york-islanders
# https://www.eliteprospects.com/team/68/new-york-rangers
# https://www.eliteprospects.com/team/69/ottawa-senators
# https://www.eliteprospects.com/team/70/philadelphia-flyers
# https://www.eliteprospects.com/team/71/pittsburgh-penguins
# https://www.eliteprospects.com/team/73/san-jose-sharks
# https://www.eliteprospects.com/team/27336/seattle-kraken
# https://www.eliteprospects.com/team/74/st.-louis-blues
# https://www.eliteprospects.com/team/75/tampa-bay-lightning
# https://www.eliteprospects.com/team/76/toronto-maple-leafs
# https://www.eliteprospects.com/team/77/vancouver-canucks
# https://www.eliteprospects.com/team/22211/vegas-golden-knights
# https://www.eliteprospects.com/team/78/washington-capitals
# https://www.eliteprospects.com/team/9966/winnipeg-jets

# %% [markdown]
# ### Parse staff listings of team for a few random years
# * 2005-2006
# * 2011-2012
# * 2015-2016
# * 2020-2021

# %%
# get list of links to NHL team pages
staff_and_links = {}
seasons = ['2005-2006', '2011-2012', '2015-2016', '2020-2021']


for team_name, team_link in team_and_links.items():
    for i in range(0, len(seasons)):
        try:
            url = team_link + '/' + seasons[i]
            page = urlopen(url)
            html = page.read().decode("utf-8")
            soup = BeautifulSoup(html, 'html.parser')

            staff_tags = soup.find('div', {'class': 'list-as-columns list-as-columns--with-border'}).find_all('a')
            for tag in staff_tags:
                staff_name = tag.get_text().strip()
                staff_link = tag.get('href')
                staff_and_links[staff_name] = staff_link
    
        except Exception as e:
            print('failed on page ' + url)
            print(e)
# Out:
# failed on page https://www.eliteprospects.com/team/27336/seattle-kraken/2005-2006
# 'NoneType' object has no attribute 'find_all'
# failed on page https://www.eliteprospects.com/team/27336/seattle-kraken/2011-2012
# 'NoneType' object has no attribute 'find_all'
# failed on page https://www.eliteprospects.com/team/27336/seattle-kraken/2015-2016
# 'NoneType' object has no attribute 'find_all'
# failed on page https://www.eliteprospects.com/team/22211/vegas-golden-knights/2005-2006
# 'NoneType' object has no attribute 'find_all'
# failed on page https://www.eliteprospects.com/team/22211/vegas-golden-knights/2011-2012
# 'NoneType' object has no attribute 'find_all'
# failed on page https://www.eliteprospects.com/team/22211/vegas-golden-knights/2015-2016
# 'NoneType' object has no attribute 'find_all'
# failed on page https://www.eliteprospects.com/team/9966/winnipeg-jets/2005-2006
# 'NoneType' object has no attribute 'find_all'

# %%
print(str(len(staff_and_links)) + ' staff members found since ' + str(seasons[0]))
# Out:
# 2257 staff members found since 2005-2006

# %%
# save this list
with open('staff_and_links.json', 'w') as f:
    json.dump(staff_and_links, f)

# %% [markdown]
# ### Parse position history of each staff member

# %%
# read file containing staff and links
with open('staff_and_links.json') as f:
    staff_and_links = json.load(f)
print(str(len(staff_and_links)) + ' staff members found in file')

# convert to list
## since eliteprospects.com has a request limit, we need to mine staff positions in chunks
## therefore, we should store this data as a list so that it is easy to pick up where we left off
staff_and_links_list = []
for name, link in staff_and_links.items():
    staff_and_links_list.append([name, link])
print('num of staff members: ' + str(len(staff_and_links_list)))
print('example of item in list: ' + str(staff_and_links_list[0]))
# Out:
# 2257 staff members found in file
# num of staff members: 2257
# example of item in list: ['Randy Carlyle', 'https://www.eliteprospects.com/staff/184/randy-carlyle']

# %%
def parse_position_table(soup, active_staff_all_time_history, name):    
    # get staff member image link
    tag = soup.find('div', {'class': 'ep-entity-header__main-image'}).get('style')
    image = tag[tag.find('files.eliteprospects.com'):tag.find('\');')]

    # get the positions held table
    positions_table = soup.find('div', {'id': 'staff-stats'})

    # create a list of each position held
    positions_table_items = positions_table.find_all('tr')

    # get season, team, league, and role on team
    season = ''
    for p in positions_table_items[1:]:
        try:
            if p.find('td', {'class': 'season sorted'}).get_text().strip() != '':
                season = p.find('td', {'class': 'season sorted'}).get_text().strip()
            team = p.find('td', {'class': 'team'}).find('span').find('a').get_text().strip()
            league = p.find('td', {'class': 'league'}).find('a').get_text().strip()
            role = p.find('td', {'class': 'role'}).get_text().strip()
            notes = p.find('td', {'class': 'notes'}).get_text().strip()

            active_staff_all_time_history.append([name, season, team, league, role, notes, image])
        except Exception:
            print('error in ' + name)
        
    return

# %%
# active_staff_all_time_history = []

# read file containing staff and positions
with open('active_staff_all_time_history.json') as f:
    active_staff_all_time_history = json.load(f)
    
print(len(active_staff_all_time_history))
# Out:
# 36558

# %%
# calculate starting point
distinct_names = set()
for row in active_staff_all_time_history:
    distinct_names.add(row[0])
distinct_names_len = len(distinct_names)
print('start at: ' + str(distinct_names_len))

try:
#     for i in range(distinct_names_len, len(staff_and_links_list)):
    for i in range(distinct_names_len, distinct_names_len + 14):
        page = urlopen(staff_and_links_list[i][1])
        html = page.read().decode("utf-8")
        soup = BeautifulSoup(html, 'html.parser')
        parse_position_table(soup, active_staff_all_time_history, staff_and_links_list[i][0])
    
except Exception as e:
    print('failed on page ' + str(staff_and_links_list[i][1]) + ' and count= ' + str(i))
    print(e)
    
# save this list
with open('active_staff_all_time_history.json', 'w') as f:
    json.dump(active_staff_all_time_history, f)
# Out:
# start at: 2059
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/ll/7dqm5ml15lb384fy0jvks7fr0000gn/T/ipykernel_38350/1452476222.py in <module>
#      11     for i in range(205, 430):
# ---> 12         page = urlopen(unmined_list[i][1])
#      13         html = page.read().decode("utf-8")
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# /var/folders/ll/7dqm5ml15lb384fy0jvks7fr0000gn/T/ipykernel_38350/1452476222.py in <module>
#      16
#      17 except Exception as e:
# ---> 18     print('failed on page ' + str(unmined_list[i][1]) + ' and count= ' + str(i))
#      19     print(e)
#      20
#
# IndexError: list index out of range

# %%
# save this list
with open('active_staff_all_time_history.json', 'w') as f:
    json.dump(active_staff_all_time_history, f)

# %%
# calculate number of distinct staff members
distinct_names = set()
for row in active_staff_all_time_history:
    distinct_names.add(row[0])
distinct_names_len = len(distinct_names)
print('distinct: ' + str(distinct_names_len))
print('total staff years: ' + str(len(active_staff_all_time_history)))
# Out:
# distinct: 2257
# total staff years: 43439

# %% [markdown]
# ### Convert to df

# %%
df = pd.DataFrame(active_staff_all_time_history)
df.columns = ['name', 'season', 'team', 'league', 'position', 'notes', 'image']
df
# Out:
#                 name   season                     team league  \
# 0      Randy Carlyle  1994-95            Winnipeg Jets    NHL
# 1      Randy Carlyle  1995-96            Winnipeg Jets    NHL
# 2      Randy Carlyle  1996-97           Manitoba Moose    IHL
# 3      Randy Carlyle  1996-97           Manitoba Moose    IHL
# 4      Randy Carlyle  1997-98           Manitoba Moose    IHL
# ...              ...      ...                      ...    ...
# 43434    Dan Shrader  2017-18            Winnipeg Jets    NHL
# 43435    Dan Shrader  2018-19            Winnipeg Jets    NHL
# 43436    Dan Shrader  2019-20            Winnipeg Jets    NHL
# 43437    Dan Shrader  2020-21            Winnipeg Jets    NHL
# 43438    Dan Shrader  2021-22  Dubuque Fighting Saints   USHL
#
#                          position                            notes  \
# 0      Dir. of Player Development
# 1                     Asst. Coach
# 2                     Asst. Coach
# 3                   GM/Head Coach  Replaced Jean Perron mid-season
# 4                   GM/Head Coach
# ...                           ...                              ...
# 43434                       Scout                    Amateur Scout
# 43435                       Scout                    Amateur Scout
# 43436                       Scout                    Amateur Scout
# 43437                       Scout                    Amateur Scout
# 43438                       Scout
#
#                                                    image
# 0      files.eliteprospects.com/layout/staff/hc-carly...
# 1      files.eliteprospects.com/layout/staff/hc-carly...
# 2      files.eliteprospects.com/layout/staff/hc-carly...
# 3      files.eliteprospects.com/layout/staff/hc-carly...
# 4      files.eliteprospects.com/layout/staff/hc-carly...
# ...                                                  ...
# 43434
# 43435
# 43436
# 43437
# 43438
#
# [43439 rows x 7 columns]

# %%
df[df['name']=='Chuck Fletcher']
# Out:
#                name   season                            team league  \
# 183  Chuck Fletcher  1993-94                Florida Panthers    NHL
# 184  Chuck Fletcher  1994-95                Florida Panthers    NHL
# 185  Chuck Fletcher  1995-96                Florida Panthers    NHL
# 186  Chuck Fletcher  1996-97                Florida Panthers    NHL
# 187  Chuck Fletcher  1997-98                Florida Panthers    NHL
# 188  Chuck Fletcher  1998-99                Florida Panthers    NHL
# 189  Chuck Fletcher  1999-00                Florida Panthers    NHL
# 190  Chuck Fletcher  1999-00             Louisville Panthers    AHL
# 191  Chuck Fletcher  2000-01                Florida Panthers    NHL
# 192  Chuck Fletcher  2000-01             Louisville Panthers    AHL
# 193  Chuck Fletcher  2001-02                Florida Panthers    NHL
# 194  Chuck Fletcher  2001-02                Florida Panthers    NHL
# 195  Chuck Fletcher  2002-03         Mighty Ducks of Anaheim    NHL
# 196  Chuck Fletcher  2002-03         Mighty Ducks of Anaheim    NHL
# 197  Chuck Fletcher  2003-04         Mighty Ducks of Anaheim    NHL
# 198  Chuck Fletcher  2003-04         Mighty Ducks of Anaheim    NHL
# 199  Chuck Fletcher  2005-06         Mighty Ducks of Anaheim    NHL
# 200  Chuck Fletcher  2005-06         Mighty Ducks of Anaheim    NHL
# 201  Chuck Fletcher  2006-07             Pittsburgh Penguins    NHL
# 202  Chuck Fletcher  2006-07  Wilkes-Barre/Scranton Penguins    AHL
# 203  Chuck Fletcher  2007-08             Pittsburgh Penguins    NHL
# 204  Chuck Fletcher  2007-08  Wilkes-Barre/Scranton Penguins    AHL
# 205  Chuck Fletcher  2008-09             Pittsburgh Penguins    NHL
# 206  Chuck Fletcher  2008-09  Wilkes-Barre/Scranton Penguins    AHL
# 207  Chuck Fletcher  2009-10                  Minnesota Wild    NHL
# 208  Chuck Fletcher  2010-11                  Minnesota Wild    NHL
# 209  Chuck Fletcher  2011-12                  Minnesota Wild    NHL
# 210  Chuck Fletcher  2012-13                  Minnesota Wild    NHL
# 211  Chuck Fletcher  2013-14                  Minnesota Wild    NHL
# 212  Chuck Fletcher  2013-14                  Minnesota Wild    NHL
# 213  Chuck Fletcher  2014-15                  Minnesota Wild    NHL
# 214  Chuck Fletcher  2014-15                  Minnesota Wild    NHL
# 215  Chuck Fletcher  2015-16                  Minnesota Wild    NHL
# 216  Chuck Fletcher  2015-16                  Minnesota Wild    NHL
# 217  Chuck Fletcher  2016-17                  Minnesota Wild    NHL
# 218  Chuck Fletcher  2016-17                  Minnesota Wild    NHL
# 219  Chuck Fletcher  2017-18                  Minnesota Wild    NHL
# 220  Chuck Fletcher  2017-18                  Minnesota Wild    NHL
# 221  Chuck Fletcher  2018-19               New Jersey Devils    NHL
# 222  Chuck Fletcher  2018-19             Philadelphia Flyers    NHL
# 223  Chuck Fletcher  2018-19             Philadelphia Flyers    NHL
# 224  Chuck Fletcher  2019-20             Philadelphia Flyers    NHL
# 225  Chuck Fletcher  2019-20             Philadelphia Flyers    NHL
# 226  Chuck Fletcher  2020-21             Philadelphia Flyers    NHL
# 227  Chuck Fletcher  2020-21             Philadelphia Flyers    NHL
#
#                         position                            notes  \
# 183        Asst. General Manager
# 184        Asst. General Manager
# 185        Asst. General Manager
# 186        Asst. General Manager
# 187        Asst. General Manager
# 188        Asst. General Manager
# 189        Asst. General Manager
# 190              General Manager
# 191        Asst. General Manager
# 192              General Manager
# 193        Asst. General Manager
# 194              General Manager  Succeeded Bill Torrey on Dec. 3
# 195        Asst. General Manager
# 196    Dir. of Hockey Operations
# 197        Asst. General Manager
# 198    Dir. of Hockey Operations
# 199        Asst. General Manager
# 200    Dir. of Hockey Operations
# 201        Asst. General Manager
# 202              General Manager
# 203        Asst. General Manager
# 204              General Manager
# 205        Asst. General Manager
# 206              General Manager
# 207              General Manager
# 208              General Manager
# 209              General Manager
# 210              General Manager
# 211  Ex. VP of Hockey Operations
# 212              General Manager
# 213  Ex. VP of Hockey Operations
# 214              General Manager
# 215  Ex. VP of Hockey Operations
# 216              General Manager
# 217  Ex. VP of Hockey Operations
# 218              General Manager
# 219  Ex. VP of Hockey Operations
# 220              General Manager
# 221               Senior Advisor                 Until December 4
# 222  Ex. VP of Hockey Operations              Hired on December 4
# 223              General Manager
# 224   Pres. of Hockey Operations
# 225              General Manager
# 226   Pres. of Hockey Operations
# 227              General Manager
#
#                                                  image
# 183  files.eliteprospects.com/layout/staff/chuck_fl...
# 184  files.eliteprospects.com/layout/staff/chuck_fl...
# 185  files.eliteprospects.com/layout/staff/chuck_fl...
# 186  files.eliteprospects.com/layout/staff/chuck_fl...
# 187  files.eliteprospects.com/layout/staff/chuck_fl...
# 188  files.eliteprospects.com/layout/staff/chuck_fl...
# 189  files.eliteprospects.com/layout/staff/chuck_fl...
# 190  files.eliteprospects.com/layout/staff/chuck_fl...
# 191  files.eliteprospects.com/layout/staff/chuck_fl...
# 192  files.eliteprospects.com/layout/staff/chuck_fl...
# 193  files.eliteprospects.com/layout/staff/chuck_fl...
# 194  files.eliteprospects.com/layout/staff/chuck_fl...
# 195  files.eliteprospects.com/layout/staff/chuck_fl...
# 196  files.eliteprospects.com/layout/staff/chuck_fl...
# 197  files.eliteprospects.com/layout/staff/chuck_fl...
# 198  files.eliteprospects.com/layout/staff/chuck_fl...
# 199  files.eliteprospects.com/layout/staff/chuck_fl...
# 200  files.eliteprospects.com/layout/staff/chuck_fl...
# 201  files.eliteprospects.com/layout/staff/chuck_fl...
# 202  files.eliteprospects.com/layout/staff/chuck_fl...
# 203  files.eliteprospects.com/layout/staff/chuck_fl...
# 204  files.eliteprospects.com/layout/staff/chuck_fl...
# 205  files.eliteprospects.com/layout/staff/chuck_fl...
# 206  files.eliteprospects.com/layout/staff/chuck_fl...
# 207  files.eliteprospects.com/layout/staff/chuck_fl...
# 208  files.eliteprospects.com/layout/staff/chuck_fl...
# 209  files.eliteprospects.com/layout/staff/chuck_fl...
# 210  files.eliteprospects.com/layout/staff/chuck_fl...
# 211  files.eliteprospects.com/layout/staff/chuck_fl...
# 212  files.eliteprospects.com/layout/staff/chuck_fl...
# 213  files.eliteprospects.com/layout/staff/chuck_fl...
# 214  files.eliteprospects.com/layout/staff/chuck_fl...
# 215  files.eliteprospects.com/layout/staff/chuck_fl...
# 216  files.eliteprospects.com/layout/staff/chuck_fl...
# 217  files.eliteprospects.com/layout/staff/chuck_fl...
# 218  files.eliteprospects.com/layout/staff/chuck_fl...
# 219  files.eliteprospects.com/layout/staff/chuck_fl...
# 220  files.eliteprospects.com/layout/staff/chuck_fl...
# 221  files.eliteprospects.com/layout/staff/chuck_fl...
# 222  files.eliteprospects.com/layout/staff/chuck_fl...
# 223  files.eliteprospects.com/layout/staff/chuck_fl...
# 224  files.eliteprospects.com/layout/staff/chuck_fl...
# 225  files.eliteprospects.com/layout/staff/chuck_fl...
# 226  files.eliteprospects.com/layout/staff/chuck_fl...
# 227  files.eliteprospects.com/layout/staff/chuck_fl...

# %%
# pd.set_option('display.max_rows', 100)
df[df['name']=='Chuck Fletcher']['position'].value_counts()
# Out:
# General Manager                18
# Asst. General Manager          15
# Ex. VP of Hockey Operations     6
# Dir. of Hockey Operations       3
# Pres. of Hockey Operations      2
# Senior Advisor                  1
# Name: position, dtype: int64

# %%
df[(df['name'] != 'Chuck Fletcher') & (df['team'] == 'Minnesota Wild') & (df['season'] == '2013-14')]
# Out:
#                name   season            team league               position  \
# 516     Brent Flahr  2013-14  Minnesota Wild    NHL  Asst. General Manager
# 587     Pavel Routa  2013-14  Minnesota Wild    NHL                  Scout
# 3541  Donnie Fuller  2013-14  Minnesota Wild    NHL       Athletic Trainer
#
#                       notes                                              image
# 516                          files.eliteprospects.com/layout/staff/flahr_br...
# 587          European Scout
# 3541  Head Athletic Trainer

# %%
# use case: find all staff members Chuck Fletcher has worked with in his career
for index, row in df[df['name'] == 'Chuck Fletcher'].iterrows():
    print(row['season'], row['team'])
    print(df[(df['name'] != 'Chuck Fletcher') & (df['team'] == row['team']) & (df['season'] == row['season'])]['name'].values)
# Out:
# 1993-94 Florida Panthers
# ['Lindy Ruff' 'Jon Christiano' 'Tom Webster' 'Tom Webster']
# 1994-95 Florida Panthers
# ['Lindy Ruff' 'Jon Christiano' 'Tim Murray']
# 1995-96 Florida Panthers
# ['Lindy Ruff' 'Tim Murray']
# 1996-97 Florida Panthers
# ['Brent Flahr' 'Wayne Meier' 'Lindy Ruff' 'Tim Murray']
# 1997-98 Florida Panthers
# ['Brent Flahr' 'Wayne Meier' 'Tim Murray']
# 1998-99 Florida Panthers
# ['Brent Flahr' 'Wayne Meier' 'Terry Murray' 'Tim Murray']
# 1999-00 Florida Panthers
# ['Brent Flahr' 'Wayne Meier' 'Pavel Routa' 'Terry Murray' 'Tim Murray']
# 1999-00 Louisville Panthers
# []
# 2000-01 Florida Panthers
# ['Brent Flahr' 'Wayne Meier' 'Pavel Routa' 'Terry Murray' 'Tim Murray']
# 2000-01 Louisville Panthers
# []
# 2001-02 Florida Panthers
# ['Brent Flahr' 'Wayne Meier' 'Pavel Routa' 'Tim Murray']
# 2001-02 Florida Panthers
# ['Brent Flahr' 'Wayne Meier' 'Pavel Routa' 'Tim Murray']
# 2002-03 Mighty Ducks of Anaheim
# ['François Allaire' 'David McNab' 'Sean Skahan' 'Alain Chainey'
#  'Jan-Åke Danielson' 'Wayne Meier' 'Paul MacLean' 'Tim Murray']
# 2002-03 Mighty Ducks of Anaheim
# ['François Allaire' 'David McNab' 'Sean Skahan' 'Alain Chainey'
#  'Jan-Åke Danielson' 'Wayne Meier' 'Paul MacLean' 'Tim Murray']
# 2003-04 Mighty Ducks of Anaheim
# ['François Allaire' 'David McNab' 'Michael Schulman' 'Sean Skahan'
#  'Alain Chainey' 'Jeff Crisp' 'Jan-Åke Danielson' 'Brent Flahr'
#  'Wayne Meier' 'Pavel Routa' 'Paul MacLean' 'Tim Murray']
# 2003-04 Mighty Ducks of Anaheim
# ['François Allaire' 'David McNab' 'Michael Schulman' 'Sean Skahan'
#  'Alain Chainey' 'Jeff Crisp' 'Jan-Åke Danielson' 'Brent Flahr'
#  'Wayne Meier' 'Pavel Routa' 'Paul MacLean' 'Tim Murray']
# 2005-06 Mighty Ducks of Anaheim
# ['Randy Carlyle' 'Newell Brown' 'Dave Farrish' 'François Allaire'
#  'Brian Burke' 'Brian Burke' 'David McNab' 'Ryan Lichtenfels'
#  'Michael Schulman' 'Sean Skahan' 'Alain Chainey' 'Rick Paterson'
#  'Henry Samueli' 'Susan Samueli' 'Jeff Crisp' 'Jan-Åke Danielson'
#  'Brent Flahr' 'Wayne Meier' 'Pavel Routa' 'Al Coates' 'Bob Murray']
# 2005-06 Mighty Ducks of Anaheim
# ['Randy Carlyle' 'Newell Brown' 'Dave Farrish' 'François Allaire'
#  'Brian Burke' 'Brian Burke' 'David McNab' 'Ryan Lichtenfels'
#  'Michael Schulman' 'Sean Skahan' 'Alain Chainey' 'Rick Paterson'
#  'Henry Samueli' 'Susan Samueli' 'Jeff Crisp' 'Jan-Åke Danielson'
#  'Brent Flahr' 'Wayne Meier' 'Pavel Routa' 'Al Coates' 'Bob Murray']
# 2006-07 Pittsburgh Penguins
# ['Wayne Meier' 'Robert Neuhauser' 'Darryl Plandowski' 'Ken Sawyer']
# 2006-07 Wilkes-Barre/Scranton Penguins
# ['Dan Bylsma']
# 2007-08 Pittsburgh Penguins
# ['Wayne Meier' 'Robert Neuhauser' 'Darryl Plandowski']
# 2007-08 Wilkes-Barre/Scranton Penguins
# ['Dan Bylsma']
# 2008-09 Pittsburgh Penguins
# ['Wayne Meier' 'Robert Neuhauser' 'Dan Bylsma']
# 2008-09 Wilkes-Barre/Scranton Penguins
# ['Dan Bylsma']
# 2009-10 Minnesota Wild
# ['Brent Flahr' 'Pavel Routa' 'Donnie Fuller' 'Dave Barr' 'Chris Snow']
# 2010-11 Minnesota Wild
# ['Brent Flahr' 'Pavel Routa' 'Donnie Fuller' 'Dave Barr']
# 2011-12 Minnesota Wild
# ['Brent Flahr' 'Pavel Routa' 'Donnie Fuller']
# 2012-13 Minnesota Wild
# ['Brent Flahr' 'Pavel Routa' 'Donnie Fuller']
# 2013-14 Minnesota Wild
# ['Brent Flahr' 'Pavel Routa' 'Donnie Fuller']
# 2013-14 Minnesota Wild
# ['Brent Flahr' 'Pavel Routa' 'Donnie Fuller']
# 2014-15 Minnesota Wild
# ['Brent Flahr' 'Pavel Routa' 'Donnie Fuller']
# 2014-15 Minnesota Wild
# ['Brent Flahr' 'Pavel Routa' 'Donnie Fuller']
# 2015-16 Minnesota Wild
# ['Brent Flahr' 'Pavel Routa' 'Donnie Fuller']
# 2015-16 Minnesota Wild
# ['Brent Flahr' 'Pavel Routa' 'Donnie Fuller']
# 2016-17 Minnesota Wild
# ['Sean Skahan' 'Brent Flahr' 'Pavel Routa' 'Bruce Boudreau'
#  'John Anderson']
# 2016-17 Minnesota Wild
# ['Sean Skahan' 'Brent Flahr' 'Pavel Routa' 'Bruce Boudreau'
#  'John Anderson']
# 2017-18 Minnesota Wild
# ['Sean Skahan' 'Brent Flahr' 'Pavel Routa' 'Bruce Boudreau' 'Bob Woods'
#  'John Anderson']
# 2017-18 Minnesota Wild
# ['Sean Skahan' 'Brent Flahr' 'Pavel Routa' 'Bruce Boudreau' 'Bob Woods'
#  'John Anderson']
# 2018-19 New Jersey Devils
# ['Greg Royce' 'Eric Weinrich' 'Steve Smith']
# 2018-19 Philadelphia Flyers
# ['Brent Flahr' 'Brent Flahr']
# 2018-19 Philadelphia Flyers
# ['Brent Flahr' 'Brent Flahr']
# 2019-20 Philadelphia Flyers
# ['Brent Flahr' 'Brent Flahr' 'Angelo Ricci']
# 2019-20 Philadelphia Flyers
# ['Brent Flahr' 'Brent Flahr' 'Angelo Ricci']
# 2020-21 Philadelphia Flyers
# ['Brent Flahr' 'Brent Flahr' 'Angelo Ricci']
# 2020-21 Philadelphia Flyers
# ['Brent Flahr' 'Brent Flahr' 'Angelo Ricci']
